# %%
list(range(2))
# Out:
# Running cells with 'env (Python 3.11.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"/Users/carlplacek/Desktop/Uni/DataScience&KI/env/bin/python" -m pip install ipykernel -U --force-reinstall'
