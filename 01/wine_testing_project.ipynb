# %% [markdown]
# # Wine Tasting - red wine

# %% [markdown]
# ### Ziel: Vorhersage der Weinqualität
# **Spezifisch**: Entwickle ein Modell, das die Qualität von Weinen mit dessen Prozentgehalt in Korrelation bringt.
#
# ***Messbar**: Ziel ist eine Vorhersagegenauigkeit (Accuracy) von mindestens 75% auf dem Testdatensatz. (machine learning)*
#
# **Attraktiv**: Das Modell hilft Winzern, Weinqualität effizient zu bewerten und Produktionsprozesse zu optimieren.
#
# **Realistisch**: Der UCI-Weindatensatz mit 178 Proben liefert ausreichend Daten, um erste Vorhersagemodelle wie Random Forest oder SVM zu trainieren.
#
# **Terminiert**: Implementierung, Training und Evaluation des Modells innerhalb von vorgegebener Zeit.

# %%
# %pip install pandas matplotlib seaborn tensorflow
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/carlplacek/Desktop/Uni/DataScience&KI/env/lib/python3.11/site-packages/pip/__main__.py", line 22, in <module>
#     from pip._internal.cli.main import main as _main
#   File "/Users/carlplacek/Desktop/Uni/DataScience&KI/env/lib/python3.11/site-packages/pip/_internal/cli/main.py", line 11, in <module>
#     from pip._internal.cli.autocompletion import autocomplete
#   File "/Users/carlplacek/Desktop/Uni/DataScience&KI/env/lib/python3.11/site-packages/pip/_internal/cli/autocompletion.py", line 12, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "/Users/carlplacek/Desktop/Uni/DataScience&KI/env/lib/python3.11/site-packages/pip/_internal/cli/main_parser.py", line 9, in <module>
#     from pip._internal.build_env import get_runnable_pip
# ...

# %% [markdown]
# ### Weinqualität vs. Alkoholgehalt

# %% [markdown]
# *Benötigte Bibliotheken importieren*
#
# *import tensorflow as tf*
#
# *CSV-Datei für Rotwein*

# %%
import pandas as pd
import matplotlib.pyplot as plt 

# CSV-Datei für Rotwein einlesen
df = pd.read_csv('/Users/carlplacek/Desktop/Uni/DataScience&KI/wine+quality/winequality-red.csv', sep=';')

# %% [markdown]
# ### Basic Datenabfragen

# %%
# Überblick
print(df.head())   # erste Zeilen anzeigen
print(df.info())   # Spalten, Datentypen, fehlende Werte
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ### Diagramm Visualisieren

# %%
# Diagramm mit pyplot visualisieren
plt.xlabel('Alcohol (%)')
plt.ylabel('Quality (0-10)')
plt.title('Alcohol vs Quality in Red Wine')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Daten extrahieren, Durchschnitt berechnen, Commando-Output

# %%
# Daten aus zwei Spalten extrahieren
x = df["alcohol"]   # unabhängige Variable (x-Achse)
y = df["quality"]   # abhängige Variable (y-Achse)

# Streudiagramm erstellen
plt.scatter(x, y, color='blue', marker='o', s=50)

# Durchschnitt berechnen
durchschnitt_alc = df["alcohol"].mean()
durchschnitt_qu = df["quality"].mean()

# Runden auf 2 Nachkommastellen
durchschnitt_gerundet_alc = round(durchschnitt_alc, 2)
durchschnitt_gerundet_qu = round(durchschnitt_qu, 2)

# Durchschnittswerte ausgeben als Ausgabe Befehl im Output
print("Durchschnitt Alkohlgehalt:", (durchschnitt_gerundet_alc), "%")
print("Durchschnitt Qualität:", (durchschnitt_gerundet_qu), "von 10")
# Out:
# Durchschnitt Alkohlgehalt: 10.42 %
# Durchschnitt Qualität: 5.64 von 10
